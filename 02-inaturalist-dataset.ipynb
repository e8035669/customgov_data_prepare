# %% [markdown]
# # 自GBIF網站下載資料集
#
# https://www.inaturalist.org/
#
# https://www.gbif.org/

# %% [markdown]
# iNaturalist網站介紹，擷取自wiki:
# > iNaturalist 簡稱 iNat，是一個藉由社交網路實現的公眾科學專案，線上運營同名生物資料庫網站和行動應用軟體，旨在讓全球各地的人們發現、記錄並分享身邊的物種資訊，使用者包括專家學者、教師、學生、自然愛好者及生物愛好者等。iNat 透過社群網路，將專業研究人員與普通群眾連接起來，使業餘觀察者隨手記錄的資料，成為生物多樣性研究的重要參考資訊。
#
# GBIF.org網站介紹，擷取自wiki:
# > 全球生物多樣性資訊機構（英文：Global Biodiversity Information Facility，縮寫為 GBIF），或稱全球生物多樣性信息網絡、全球生物多樣性資訊設施，是2001年在世界多國政府資助下成立的一個國際組織，由丹麥哥本哈根大學公園內的 GBIF 祕書處運作管理，線上運營同名生物學資料庫，旨在向大眾提供無論何時何地均能公開且自由存取的地球上各種生物的資料。GBIF 以參與國、合作組織作為節點，各節點收集的資料以共同標準、開源格式提供給全球的資料中心，使得這些包含記錄地點、時間的生物資訊得以公開分享。這些生物資訊來源不一，有來自18–19世紀的博物館標本典藏，到近年來業餘學者們發布的附有地理標記的相片。

# %% [markdown]
# iNaturalist網站似乎會定期同步觀察資料到gbif網站，而我們可以在gbif網站註冊帳號，可以下載我們所需的資料集。

# %% [markdown]
# 我自己在gbif網站上下載的資料集，這個資料集的過濾條件是 台灣的 iNaturalist網站的 蝴蝶資料集。
#
# https://www.gbif.org/occurrence/download/0372200-210914110416597
#
# ![img06](img/img06.png)

# %% [markdown]
# ## 下載資料集
#
# 首先，先下載蝴蝶的資料集，並且將它解壓縮

# %%
import os
import requests
import shutil
import random
import pandas as pd
from glob import glob

random.seed(47)

# %%
dataset_url = 'https://api.gbif.org/v1/occurrence/download/request/0372200-210914110416597.zip'
dataset_name = os.path.basename(dataset_url)
dirname = os.path.splitext(dataset_name)[0]

# %%
# 下載檔案
with requests.get(dataset_url, stream=True) as res:
    with open(dataset_name, 'wb') as f:
        for chunk in res.iter_content(chunk_size=4096):
            f.write(chunk)

# %%
# 解壓縮壓縮檔
shutil.unpack_archive(dataset_name, dirname)

# %%
glob(dirname + '/*')
# Out:
# ['0372200-210914110416597/verbatim.txt',
#  '0372200-210914110416597/dataset',
#  '0372200-210914110416597/citations.txt',
#  '0372200-210914110416597/occurrence.txt',
#  '0372200-210914110416597/rights.txt',
#  '0372200-210914110416597/multimedia.txt',
#  '0372200-210914110416597/meta.xml',
#  '0372200-210914110416597/metadata.xml']

# %% [markdown]
# 解壓縮後，可以看到資料夾內有許多txt檔與xml檔。其中`occurrence.txt`與`multimedia.txt`是最重要的檔案
#
# 這兩個txt檔都是類似csv格式，但是是以tab為分隔每個欄位。用Windows的Excel應也能開啟，但資料量大，可能會很卡。
# `occurrence.txt`是包含觀察紀錄的表格，每一筆紀錄都是某個人的觀察紀錄，紀錄觀察的人事時地物，也包含鑑定出的物種。
# `multimedia.txt`裡面有觀察拍攝的所有照片的下載連結，每筆紀錄為一張照片，可對應到。一個觀察記錄可能會拍攝多張照片，都會記錄在這個表格中。

# %%
occurrence = pd.read_csv(os.path.join(dirname, 'occurrence.txt'), sep='\t')
multimedia = pd.read_csv(os.path.join(dirname, 'multimedia.txt'), sep='\t')
# Out:
# /tmp/ipykernel_1159609/3682588679.py:1: DtypeWarning: Columns (71,175) have mixed types. Specify dtype option on import or set low_memory=False.
#   occurrence = pd.read_csv(os.path.join(dirname, 'occurrence.txt'), sep='\t')

# %%
display(occurrence.head())
display(multimedia.head())
# Out:
#        gbifID  abstract  accessRights  accrualMethod  accrualPeriodicity  \
# 0  3802823405       NaN           NaN            NaN                 NaN
# 1  3802820558       NaN           NaN            NaN                 NaN
# 2  3802820005       NaN           NaN            NaN                 NaN
# 3  3802819694       NaN           NaN            NaN                 NaN
# 4  3802819314       NaN           NaN            NaN                 NaN
#
#    accrualPolicy  alternative  audience  available  bibliographicCitation  \
# 0            NaN          NaN       NaN        NaN                    NaN
# 1            NaN          NaN       NaN        NaN                    NaN
# 2            NaN          NaN       NaN        NaN                    NaN
# 3            NaN          NaN       NaN        NaN                    NaN
# 4            NaN          NaN       NaN        NaN                    NaN
#
#    ...  relativeOrganismQuantity  level0Gid      level0Name  level1Gid  \
# 0  ...                       NaN        TWN  Chinese Taipei    TWN.6_1
# 1  ...                       NaN        TWN  Chinese Taipei    TWN.7_1
# 2  ...                       NaN        TWN  Chinese Taipei    TWN.7_1
# 3  ...                       NaN        TWN  Chinese Taipei    TWN.2_1
# 4  ...                       NaN        TWN  Chinese Taipei    TWN.4_1
#
#    level1Name   level2Gid  level2Name  level3Gid  level3Name  \
# 0      Taipei   TWN.6.1_1      Taipei        NaN         NaN
# 1      Taiwan  TWN.7.15_1       Yulin        NaN         NaN
# 2      Taiwan  TWN.7.12_1     Taitung        NaN         NaN
# 3   Kaohsiung   TWN.2.1_1   Kaohsiung        NaN         NaN
# 4    Taichung   TWN.4.1_1    Taichung        NaN         NaN
#
#    iucnRedListCategory
# 0                   NE
# 1                  NaN
# 2                   NE
# 3                   NE
# 4                  NaN
#
# [5 rows x 257 columns]
#        gbifID        type      format  \
# 0  3802823405  StillImage  image/jpeg
# 1  3802823405  StillImage  image/jpeg
# 2  3802823405  StillImage  image/jpeg
# 3  3802820558  StillImage  image/jpeg
# 4  3802820005  StillImage  image/jpeg
#
#                                           identifier  \
# 0  https://inaturalist-open-data.s3.amazonaws.com...
# 1  https://inaturalist-open-data.s3.amazonaws.com...
# 2  https://inaturalist-open-data.s3.amazonaws.com...
# 3  https://inaturalist-open-data.s3.amazonaws.com...
# 4  https://inaturalist-open-data.s3.amazonaws.com...
#
#                                      references  title  description  source  \
# 0  https://www.inaturalist.org/photos/200193088    NaN          NaN     NaN
# 1  https://www.inaturalist.org/photos/200193099    NaN          NaN     NaN
# 2  https://www.inaturalist.org/photos/200193072    NaN          NaN     NaN
# 3  https://www.inaturalist.org/photos/200402293    NaN          NaN     NaN
# 4  https://www.inaturalist.org/photos/200872946    NaN          NaN     NaN
#
#    audience               created     creator  contributor    publisher  \
# 0       NaN  2022-05-23T23:27:44Z     amygoog          NaN  iNaturalist
# 1       NaN  2022-05-23T23:27:44Z     amygoog          NaN  iNaturalist
# 2       NaN  2022-05-23T23:27:44Z     amygoog          NaN  iNaturalist
# 3       NaN  2022-05-24T23:07:00Z        Hong          NaN  iNaturalist
# 4       NaN  2022-05-26T06:17:30Z  lijeanliao          NaN  iNaturalist
#
#                                           license rightsHolder
# 0  http://creativecommons.org/licenses/by-nc/4.0/      amygoog
# 1  http://creativecommons.org/licenses/by-nc/4.0/      amygoog
# 2  http://creativecommons.org/licenses/by-nc/4.0/      amygoog
# 3  http://creativecommons.org/licenses/by-nc/4.0/         Hong
# 4  http://creativecommons.org/licenses/by-nc/4.0/   lijeanliao

# %% [markdown]
# `multimedia`的檔案中，欄位較少，簡單觀察就能看出他們的意義。這邊挑重要的列出。
#
# 1. gbifID: 觀察紀錄的ID，可以對應到occurrence裡的gbifID欄位
# 2. identifier: 照片的下載連結。
# 3. reference: 照片在inaturalist網站的網址

# %% [markdown]
# `occurrence`的檔案中，欄位非常多，這邊挑選出較重要的欄位。
#
# 1. gbifID: 算是觀察紀錄的ID
# 2. references: 觀察記錄的網址
# 3. kingdom, pyhlum, class, order, family分別代表 界、門、綱、目、科。因為已經過濾過只有蝴蝶，這幾個欄位幾乎都一樣。
# 4. genus, specificEpithet 物種的屬名和種名。
# 5. taxonRank代表鑑定等級，最差有可能只鑑定到科別，通常可以鑑定到種名，甚至是亞種。在這邊我們要挑選鑑定等級到種或亞種的。

# %% [markdown]
# 我們先把`occurrence`的資料挑重要欄位出來，這樣較容易觀察。

# %%
occurs1 = occurrence[['gbifID', 'references', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'specificEpithet', 'taxonRank']]
occurs1
# Out:
#            gbifID                                         references  \
# 0      3802823405  https://www.inaturalist.org/observations/11848...
# 1      3802820558  https://www.inaturalist.org/observations/11860...
# 2      3802820005  https://www.inaturalist.org/observations/11886...
# 3      3802819694  https://www.inaturalist.org/observations/11862...
# 4      3802819314  https://www.inaturalist.org/observations/11835...
# ...           ...                                                ...
# 24813  1144284567   https://www.inaturalist.org/observations/2112172
# 24814  1135522961   https://www.inaturalist.org/observations/1140734
# 24815  1098894587   https://www.inaturalist.org/observations/1112350
# 24816  1088893997    https://www.inaturalist.org/observations/839401
# 24817   891019982     https://www.inaturalist.org/observations/74311
#
#         kingdom      phylum    class        order        family       genus  \
# 0      Animalia  Arthropoda  Insecta  Lepidoptera   Nymphalidae    Ideopsis
# 1      Animalia  Arthropoda  Insecta  Lepidoptera   Hesperiidae    Telicota
# 2      Animalia  Arthropoda  Insecta  Lepidoptera      Pieridae  Catopsilia
# 3      Animalia  Arthropoda  Insecta  Lepidoptera   Hesperiidae    Telicota
# 4      Animalia  Arthropoda  Insecta  Lepidoptera   Nymphalidae   Polygonia
# ...         ...         ...      ...          ...           ...         ...
# 24813  Animalia  Arthropoda  Insecta  Lepidoptera  Papilionidae     Papilio
# 24814  Animalia  Arthropoda  Insecta  Lepidoptera   Nymphalidae     Junonia
# 24815  Animalia  Arthropoda  Insecta  Lepidoptera  Papilionidae    Graphium
# 24816  Animalia  Arthropoda  Insecta  Lepidoptera  Papilionidae    Graphium
# 24817  Animalia  Arthropoda  Insecta  Lepidoptera      Pieridae      Appias
#
#       specificEpithet   taxonRank
# 0             similis     SPECIES
# 1            bambusae  SUBSPECIES
# 2              pomona     SPECIES
# 3            bambusae     SPECIES
# 4            c-aureum  SUBSPECIES
# ...               ...         ...
# 24813          bianor     SPECIES
# 24814        lemonias     SPECIES
# 24815        sarpedon     SPECIES
# 24816        sarpedon  SUBSPECIES
# 24817           indra  SUBSPECIES
#
# [24818 rows x 10 columns]

# %% [markdown]
# 接下來我們要過濾`taxonRank`檢定品質夠高的觀察紀錄，不夠高的要剃除。原本有24818個觀察記錄，濾完之後還有24700個。

# %%
occurs2 = occurs1[occurs1['taxonRank'].isin(['SPECIES', 'SUBSPECIES'])]
occurs2
# Out:
#            gbifID                                         references  \
# 0      3802823405  https://www.inaturalist.org/observations/11848...
# 1      3802820558  https://www.inaturalist.org/observations/11860...
# 2      3802820005  https://www.inaturalist.org/observations/11886...
# 3      3802819694  https://www.inaturalist.org/observations/11862...
# 4      3802819314  https://www.inaturalist.org/observations/11835...
# ...           ...                                                ...
# 24813  1144284567   https://www.inaturalist.org/observations/2112172
# 24814  1135522961   https://www.inaturalist.org/observations/1140734
# 24815  1098894587   https://www.inaturalist.org/observations/1112350
# 24816  1088893997    https://www.inaturalist.org/observations/839401
# 24817   891019982     https://www.inaturalist.org/observations/74311
#
#         kingdom      phylum    class        order        family       genus  \
# 0      Animalia  Arthropoda  Insecta  Lepidoptera   Nymphalidae    Ideopsis
# 1      Animalia  Arthropoda  Insecta  Lepidoptera   Hesperiidae    Telicota
# 2      Animalia  Arthropoda  Insecta  Lepidoptera      Pieridae  Catopsilia
# 3      Animalia  Arthropoda  Insecta  Lepidoptera   Hesperiidae    Telicota
# 4      Animalia  Arthropoda  Insecta  Lepidoptera   Nymphalidae   Polygonia
# ...         ...         ...      ...          ...           ...         ...
# 24813  Animalia  Arthropoda  Insecta  Lepidoptera  Papilionidae     Papilio
# 24814  Animalia  Arthropoda  Insecta  Lepidoptera   Nymphalidae     Junonia
# 24815  Animalia  Arthropoda  Insecta  Lepidoptera  Papilionidae    Graphium
# 24816  Animalia  Arthropoda  Insecta  Lepidoptera  Papilionidae    Graphium
# 24817  Animalia  Arthropoda  Insecta  Lepidoptera      Pieridae      Appias
#
#       specificEpithet   taxonRank
# 0             similis     SPECIES
# 1            bambusae  SUBSPECIES
# 2              pomona     SPECIES
# 3            bambusae     SPECIES
# 4            c-aureum  SUBSPECIES
# ...               ...         ...
# 24813          bianor     SPECIES
# 24814        lemonias     SPECIES
# 24815        sarpedon     SPECIES
# 24816        sarpedon  SUBSPECIES
# 24817           indra  SUBSPECIES
#
# [24700 rows x 10 columns]

# %% [markdown]
# 接下來要來做inner join，我們用兩個資料表的gbifID欄位來進行join。
# 並且只要留下必要欄位就好。
#
# 如此一來就能夠對圖片一一下載，再依據屬名和種名放到正確的分類資料夾中。

# %%
medias = multimedia[['gbifID', 'identifier']].merge(occurs2[['gbifID', 'genus', 'specificEpithet']], left_on='gbifID', right_on='gbifID')
medias
# Out:
#            gbifID                                         identifier  \
# 0      3802823405  https://inaturalist-open-data.s3.amazonaws.com...
# 1      3802823405  https://inaturalist-open-data.s3.amazonaws.com...
# 2      3802823405  https://inaturalist-open-data.s3.amazonaws.com...
# 3      3802820558  https://inaturalist-open-data.s3.amazonaws.com...
# 4      3802820005  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 36746  1135522961  https://inaturalist-open-data.s3.amazonaws.com...
# 36747  1098894587  https://inaturalist-open-data.s3.amazonaws.com...
# 36748  1088893997  https://inaturalist-open-data.s3.amazonaws.com...
# 36749  1088893997  https://inaturalist-open-data.s3.amazonaws.com...
# 36750   891019982  https://inaturalist-open-data.s3.amazonaws.com...
#
#             genus specificEpithet
# 0        Ideopsis         similis
# 1        Ideopsis         similis
# 2        Ideopsis         similis
# 3        Telicota        bambusae
# 4      Catopsilia          pomona
# ...           ...             ...
# 36746     Junonia        lemonias
# 36747    Graphium        sarpedon
# 36748    Graphium        sarpedon
# 36749    Graphium        sarpedon
# 36750      Appias           indra
#
# [36751 rows x 4 columns]

# %%
medias1 = medias[~medias.isna().any(axis='columns')]
medias1 = medias1.reset_index(drop=True)
medias1
# Out:
#            gbifID                                         identifier  \
# 0      3802823405  https://inaturalist-open-data.s3.amazonaws.com...
# 1      3802823405  https://inaturalist-open-data.s3.amazonaws.com...
# 2      3802823405  https://inaturalist-open-data.s3.amazonaws.com...
# 3      3802820558  https://inaturalist-open-data.s3.amazonaws.com...
# 4      3802820005  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 36743  1135522961  https://inaturalist-open-data.s3.amazonaws.com...
# 36744  1098894587  https://inaturalist-open-data.s3.amazonaws.com...
# 36745  1088893997  https://inaturalist-open-data.s3.amazonaws.com...
# 36746  1088893997  https://inaturalist-open-data.s3.amazonaws.com...
# 36747   891019982  https://inaturalist-open-data.s3.amazonaws.com...
#
#             genus specificEpithet
# 0        Ideopsis         similis
# 1        Ideopsis         similis
# 2        Ideopsis         similis
# 3        Telicota        bambusae
# 4      Catopsilia          pomona
# ...           ...             ...
# 36743     Junonia        lemonias
# 36744    Graphium        sarpedon
# 36745    Graphium        sarpedon
# 36746    Graphium        sarpedon
# 36747      Appias           indra
#
# [36748 rows x 4 columns]

# %% [markdown]
# 我們對這個資料表用for迴圈跑，逐一下載圖片。

# %%
def download_file(url: str, path: str):
    '''給予URL和儲存路徑，將檔案下載儲存'''
    response = requests.get(url)
    if response.status_code == 200:
        with open(path, 'wb') as f:
            f.write(response.content)
    else:
        print('Download', url, 'failed:', response.status_code, response.reason)

# %%
count = 5
for row in medias1.itertuples():
    print(row)
    count -= 1
    if count <= 0:
        break
# Out:
# Pandas(Index=0, gbifID=3802823405, identifier='https://inaturalist-open-data.s3.amazonaws.com/photos/200193088/original.jpg', genus='Ideopsis', specificEpithet='similis')
# Pandas(Index=1, gbifID=3802823405, identifier='https://inaturalist-open-data.s3.amazonaws.com/photos/200193099/original.jpg', genus='Ideopsis', specificEpithet='similis')
# Pandas(Index=2, gbifID=3802823405, identifier='https://inaturalist-open-data.s3.amazonaws.com/photos/200193072/original.jpg', genus='Ideopsis', specificEpithet='similis')
# Pandas(Index=3, gbifID=3802820558, identifier='https://inaturalist-open-data.s3.amazonaws.com/photos/200402293/original.jpeg', genus='Telicota', specificEpithet='bambusae')
# Pandas(Index=4, gbifID=3802820005, identifier='https://inaturalist-open-data.s3.amazonaws.com/photos/200872946/original.jpg', genus='Catopsilia', specificEpithet='pomona')

# %% [markdown]
# 真的下載會需要一段時間，下載完成之後的資料夾排列方式跟上次相同。
#
# 目錄內有許多資料夾，資料夾名稱都是各個蝴蝶的學名。資料夾再進去就是該物種的所有圖片。如此的擺放方式適合訓練分類模型。

# %%
# root_dir = 'gbif_dataset'
# for row in medias1.itertuples():
#     directory = os.path.join(root_dir,
#                              '{}_{}'.format(row.genus, row.specificEpithet))
#     os.makedirs(directory, exist_ok=True)
#     path = os.path.join(directory,
#                         'img{:05d}_{}'.format(row.Index, os.path.basename(row.identifier)))
#     print('Write', path)
#     download_file(row.identifier, path)

# %% [markdown]
# ##
#
# 接著來製作索引檔，並且順便在索引檔中區分train, test以及valid的資料集。
#
# 這邊的範例預計拆成train 90%, test 5%, valid 5%，比例基本上可以隨個人調配，不一定要一樣。

# %%
all_length = len(medias1)
test_length = int(all_length * 0.05)
valid_length = int(all_length * 0.05)
train_length = all_length - test_length - valid_length

print('Train:', train_length)
print('Test:', test_length)
print('Valid:', valid_length)

dataset = ['train'] * train_length + ['test'] * test_length + ['valid'] * valid_length
random.shuffle(dataset)
# Out:
# Train: 33074
# Test: 1837
# Valid: 1837

# %% [markdown]
# 接著，我們把亂數洗牌過的資料集區分，與`media1`的資料合併，並且整理出索引檔的內容。

# %%
root_dir = 'gbif_dataset'

dataset_index = []

for row, s in zip(medias1.itertuples(), dataset):
    label = '{}_{}'.format(row.genus, row.specificEpithet)
    directory = os.path.join(root_dir, label)
    path = os.path.join(directory,
                        'img{:05d}_{}'.format(row.Index, os.path.basename(row.identifier)))
    dataset_index.append([path, label, s])

# %% [markdown]
# 內容大致上先放進list之後，把他製作成pandas的DataFrame。再稍作排序，排序只是為了給人類看。

# %%
dataset_frame = pd.DataFrame(dataset_index, columns=['filepaths', 'labels', 'data set'])
dataset_frame = dataset_frame.sort_values(by=['data set', 'labels', 'filepaths'], axis='index')
dataset_frame
# Out:
#                                                filepaths  \
# 18587  gbif_dataset/Abraximorpha_davidii/img18587_ori...
# 13656    gbif_dataset/Abrota_ganga/img13656_original.jpg
# 3115   gbif_dataset/Acraea_issoria/img03115_original....
# 3179   gbif_dataset/Acraea_issoria/img03179_original.jpg
# 3657   gbif_dataset/Acraea_issoria/img03657_original....
# ...                                                  ...
# 15079    gbif_dataset/Zizula_hylax/img15079_original.jpg
# 22757    gbif_dataset/Zizula_hylax/img22757_original.jpg
# 33800    gbif_dataset/Zizula_hylax/img33800_original.jpg
# 34853    gbif_dataset/Zizula_hylax/img34853_original.jpg
# 19195  gbif_dataset/Zophoessa_siderea/img19195_origin...
#
#                      labels data set
# 18587  Abraximorpha_davidii     test
# 13656          Abrota_ganga     test
# 3115         Acraea_issoria     test
# 3179         Acraea_issoria     test
# 3657         Acraea_issoria     test
# ...                     ...      ...
# 15079          Zizula_hylax    valid
# 22757          Zizula_hylax    valid
# 33800          Zizula_hylax    valid
# 34853          Zizula_hylax    valid
# 19195     Zophoessa_siderea    valid
#
# [36748 rows x 3 columns]

# %% [markdown]
# 最後匯出成csv格式的索引檔

# %%
dataset_frame.to_csv('butterflies.csv', index=False)

# %% [markdown]
# ## 製作類別索引
#
# 接著我們來製作類別的索引檔，不過基本上只有要記錄所有類別有哪些，以及他們的順序而已，簡單的txt檔就足以應付。

# %%
classes = sorted(set(dataset_frame['labels']))

# %%
classes[:5]
# Out:
# ['Abisara_burnii',
#  'Abraximorpha_davidii',
#  'Abrota_ganga',
#  'Acraea_issoria',
#  'Acytolepis_puspa']

# %%
with open('classes.txt', 'w') as f:
    for cls in classes:
        f.write(cls)
        f.write('\n')
